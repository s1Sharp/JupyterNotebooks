# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 

html = urlopen('https://en.wikipedia.org/wiki/Kazan_Federal_University')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #mw-head
# #p-search
# /wiki/File:KFU_logo_2015.svg
# /wiki/Public_university
# #cite_note-1
# /wiki/Rector_(academia)
# /wiki/Kazan
# /wiki/Tatarstan
# /wiki/Russia
# //tools.wmflabs.org/geohack/geohack.php?pagename=Kazan_Federal_University&params=55.7907_N_49.1219_E_source:ruwiki_region:RU_scale:2000_type:edu
# /wiki/Geographic_coordinate_system
# //tools.wmflabs.org/geohack/geohack.php?pagename=Kazan_Federal_University&params=55.7907_N_49.1219_E_source:ruwiki_region:RU_scale:2000_type:edu
# /wiki/Urban_area
# /wiki/Suburban
# /wiki/School_colors
# http://www.kpfu.ru/main_page?p_sub=16
# /wiki/Russian_language
# /wiki/Tatar_language
# /wiki/Kazan
# /wiki/Russia
# /wiki/Mathematician
# /wiki/Nikolai_Ivanovich_Lobachevsky
# /wiki/Rector_(academia)
# /wiki/Lenin
# /wiki/Aleksandr_Butlerov
# /wiki/Vladimir_Markovnikov
# /wiki/Aleksandr_Arbuzov
# /wiki/Electron_spin_resonance
# /wiki/Evgeny_Zavoisky
# #History
# #Imperial_period
# #Soviet_period
# #21st_century
# #Campus
# #Organization
# #Global_cooperation
# #Library
# #Notable_faculty_and_alumni
# #Politics
# #Mathematics_and_sciences
# #Humanities:_music_and_art
# #Literature
# #Education
# #See_also
# #References
# #Further_reading
# #External_links
# /w/index.php?title=Kazan_Federal_University&action=edit&section=1
# /wiki/Nikolai_Lobachevsky
# /wiki/Ruthenium
# /wiki/Aleksandr_Butlerov
# /wiki/Yevgeny_Zavoisky
# /wiki/Semen_Altshuler
# /wiki/Aleksandr_Arbuzov
# /wiki/Vladimir_Lenin
# /wiki/Sergei_Aksakov
# /wiki/Leo_Tolstoy
# /wiki/Pavel_Ivanovich_Melnikov
# /wiki/Velimir_Khlebnikov
# /wiki/Mily_Balakirev
# /w/index.php?title=Valery_Yakobi&action=edit&redlink=1
# /wiki/File:KGU_main_building.jpg
# /wiki/File:KGU_main_building.jpg
# /w/index.php?title=Kazan_Federal_University&action=edit&section=2
# /wiki/File:Alex1.jpg
# /wiki/File:Alex1.jpg
# /wiki/Alexander_I_of_Russia
# /wiki/Alexander_I_of_Russia
# /wiki/Moscow_State_University
# /w/index.php?title=M._L._Magnitsky&action=edit&redlink=1
# /wiki/Alexander_I_of_Russia
# /wiki/Wikipedia:Citation_needed
# /wiki/File:Kazan_University,_1832.jpg
# /wiki/File:Kazan_University,_1832.jpg
# /wiki/Jan_Baudouin_de_Courtenay
# /wiki/File:Lenin-circa-1887.jpg
# /wiki/File:Lenin-circa-1887.jpg
# /wiki/Lenin
# /wiki/Karl_Ernst_Claus
# /wiki/Ruthenium
# /wiki/Alexander_II_of_Russia
# /wiki/Vladimir_Ilyich_Ulyanov
# /wiki/Lenin
# /wiki/Soviet_Union
# #cite_note-2
# /wiki/Russian_Civil_War
# /wiki/Tomsk
# /wiki/Irkutsk
# /w/index.php?title=Kazan_Federal_University&action=edit&section=3
# /wiki/Council_of_People%27s_Commissars
# /wiki/File:Kazan_State_University_with_arabic.jpg
# /wiki/File:Kazan_State_University_with_arabic.jpg
# /wiki/RSFSR
# /wiki/All-Russian_Central_Executive_Committee
# #cite_note-3
# /wiki/Vladimir_Lenin
# /wiki/Kazan_State_Medical_University
# /wiki/Soviet_Academy_of_Sciences
# /wiki/Order_of_the_Red_Banner_of_Labour
# /wiki/Order_of_Lenin
# /w/index.php?title=Kazan_Federal_University&action=edit&section=4
# /wiki/Dmitry_Medvedev
# /wiki/Decree_of_the_President_of_Russia
# /wiki/Volga_Federal_University
# #cite_note-4
# #cite_note-5
# /wiki/Tatar_State_University_of_Humanities_and_Education
# /wiki/Kazan_State_Finance_and_Economics_Institute
# #cite_note-6
# http://kpfu.ru/eng/about-university/ilshat-gafurov
# /wiki/Elabuga
# #cite_note-7
# #cite_note-8
# /wiki/Order_of_the_Government_of_Russia
# /w/index.php?title=Kazan_Federal_University&action=edit&section=5
# /wiki/Kazan_Kremlin
# /wiki/Alexander_Butlerov_Chemistry_Institute
# /wiki/Stalinist_architecture
# /wiki/Boris_Yeltsin
# /wiki/Yevgeny_Zavoisky
# /wiki/2013_Summer_Universiade
# /wiki/File:Kazan_new_ac_build_and_lib.JPG
# /wiki/File:KFU_physics_institute.jpg
# /wiki/File:Kazan_State_University_from_the_2_Korpus.jpg
# /wiki/File:KFU_chemical_institute.jpg
# /wiki/File:Kazan_sport_and_concert.JPG
# /wiki/File:Kazan_uni_observ.JPG
# /w/index.php?title=Kazan_Federal_University&action=edit&section=6
# /wiki/Naberezhnye_Chelny
# /wiki/Yelabuga
# /wiki/Leo_Tolstoy_Institute_of_Philology_and_Intercultural_Communication
# /w/index.php?title=Kazan_Federal_University&action=edit&section=7
# /wiki/Karl_Fuchs_(museum_founder)
# #cite_note-9
# #cite_note-10
# #cite_note-11
# #cite_note-12
# #cite_note-13
# /wiki/Vladimir_Minkin
# /wiki/Alexei_Starobinsky
# /w/index.php?title=Ichak_Kalderon_Adizes&action=edit&redlink=1
# /wiki/Rashid_Sunyaev
# /wiki/Anatole_Abragam
# /wiki/Karl_Alexander_M%C3%BCller
# /wiki/Brebis_Bleaney
# /wiki/Ryoji_Noyori
# /wiki/Mikhail_Piotrovsky
# /wiki/Vitaly_Ginzburg
# #cite_note-14
# #cite_note-15
# #cite_note-16
# #cite_note-17
# #cite_note-18
# #cite_note-19
# #cite_note-20
# #cite_note-21
# #cite_note-22
# /w/index.php?title=Kazan_Federal_University&action=edit&section=8
# /wiki/File:KFU_Library.jpeg
# /wiki/File:KFU_Library.jpeg
# /wiki/Grigori_Alexandrovich_Potemkin
# /w/index.php?title=V._Polyansky&action=edit&redlink=1
# /w/index.php?title=N._Bulich&action=edit&redlink=1
# /wiki/Solovetsky_Monastery
# /wiki/Mansur_Al-Hallaj
# /wiki/Avicenna
# /w/index.php?title=Ashshakhrestani&action=edit&redlink=1
# /wiki/Pentateuch
# /wiki/The_Apostle
# /w/index.php?title=Books_of_Kingdoms&action=edit&redlink=1
# /wiki/Francisco_Skorin
# /w/index.php?title=Code_of_Tsar_Alexis_Mikhailovich&action=edit&redlink=1
# /wiki/Pushkin
# /wiki/Aleksander_Griboyedov
# /wiki/Gogol
# /w/index.php?title=Nas%C3%ADri&action=edit&redlink=1
# /wiki/Tuqay
# /w/index.php?title=Kazan_Federal_University&action=edit&section=9
# /wiki/File:5216-0057-reverse.png
# /wiki/File:Celebrating_the_birthday_of_Lobachevsky.JPG
# /wiki/File:Celebrating_the_birthday_of_Lobachevsky.JPG
# /wiki/Nikolai_Ivanovich_Lobachevsky
# /wiki/Volga
# /w/index.php?title=Kazan_Federal_University&action=edit&section=10
# /wiki/Sergey_Aksakov
# /wiki/Vladimir_Lenin
# /wiki/Alexei_Rykov
# /wiki/X%C3%B6s%C3%A4yen_Yama%C5%9Fev
# /wiki/Sergei_Bakinsky
# /wiki/Vasili_Osipanov
# /wiki/Nikolai_Semashko_(medicine)
# /wiki/Dmitry_Karakozov
# /wiki/Nikolay_Fyodorov_(politician)
# /w/index.php?title=Kazan_Federal_University&action=edit&section=11
# /wiki/Aleksandr_Erminingeldovich_Arbuzov
# /wiki/Nikolai_Chebotaryov
# /wiki/Aleksandr_Mikhailovich_Butlerov
# /wiki/Naum_Meiman
# /wiki/Kimal_Akishev
# /wiki/Nikolai_Ivanovich_Lobachevsky
# /wiki/Ivan_Mikhailovich_Simonov
# /wiki/Vladimir_Vasilyevich_Markovnikov
# /wiki/Konstantin_Mereschkowski
# /wiki/Nikolay_Nikolayevich_Beketov
# /wiki/Nikolay_Zinin
# /wiki/Alexander_Mikhaylovich_Zaytsev
# /wiki/Sergey_Reformatsky
# /wiki/Alexander_Alexandrovich_Vishnevsky
# /wiki/Liverij_Osipovich_Darkshevich
# /wiki/Platon_Poretsky
# /wiki/Nikolai_Brashman
# /wiki/Karl_Ernst_Claus
# /wiki/Joseph_Johann_Littrow
# /wiki/Johann_Christian_Martin_Bartels
# /wiki/Adolph_Theodor_Kupffer
# /wiki/Marian_Albertovich_Kowalski
# /wiki/Aleksandr_Kotelnikov
# /wiki/Mikhail_Lavrentyev
# /wiki/Yevgeny_Zavoisky
# /wiki/Roald_Sagdeev
# /wiki/Vladimir_Engelgardt
# /wiki/Alexander_Luria
# /wiki/Dmitry_Dubyago
# /wiki/Alexander_Dubyago
# /wiki/Georgii_Frederiks
# /wiki/Semen_Altshuler
# /wiki/Mikhail_Lyapunov
# /wiki/Dmitrii_Sintsov
# /wiki/Oskar_Anderson
# /wiki/Wilhelm_Anderson
# /w/index.php?title=Vladimir_Galkin&action=edit&redlink=1
# /wiki/Kadir_Timergazin
# /wiki/Vladimir_Moskovkin
# /wiki/Emmanuel_Rashba
# /w/index.php?title=Kazan_Federal_University&action=edit&section=12
# /wiki/Mily_Balakirev
# /wiki/Stanislav_Govorukhin
# /wiki/Ilya_Ulyanov
# /wiki/Stepan_Smolensky
# /wiki/Karl_Fuchs_(museum_founder)
# /wiki/Michael_Minsky
# /wiki/Yuliya_Zaripova
# /wiki/Oleg_Saitov
# /w/index.php?title=Kazan_Federal_University&action=edit&section=13
# /wiki/Pavel_Ivanovich_Melnikov
# /wiki/Velimir_Khlebnikov
# /wiki/Pyotr_Boborykin
# /wiki/Eugenia_Ginzburg
# /wiki/Leo_Tolstoy
# /wiki/Daniil_Mordovtsev
# /wiki/Alexander_Tarasov-Rodionov
# /w/index.php?title=Kazan_Federal_University&action=edit&section=14
# /wiki/Jan_Niecis%C5%82aw_Baudouin_de_Courtenay
# /wiki/Vladimir_Bekhterev
# /wiki/Miko%C5%82aj_Kruszewski
# /wiki/Ivan_Yakovlev_(educator)
# /wiki/Vladimir_Burtsev
# /wiki/Peter_Lesgaft
# /wiki/Sergey_Malov
# /wiki/Nikolay_Ilminsky
# /wiki/Afanasy_Shchapov
# /wiki/Christian_Martin_Fr%C3%A4hn
# /wiki/Alexander_Kasimovich_Kazembek
# /wiki/Nicolai_A._Vasiliev
# /wiki/Vasily_Vasilyev
# /wiki/J%C3%B3zef_Kowalewski
# /wiki/Nikolay_Likhachyov
# /wiki/Nikolay_Neprimerov
# /wiki/Vasili_Razumovsky
# /wiki/Walter_Anderson_(folklorist)
# /wiki/Valentin_A._Bazhanov
# /w/index.php?title=Kazan_Federal_University&action=edit&section=15
# /wiki/File:Stamp-russia2004-kazan-state-university.png
# /wiki/File:Stamp-russia2004-kazan-state-university.png
# /wiki/Education_in_Russia
# /wiki/List_of_modern_universities_in_Europe_(1801%E2%80%931945)
# /wiki/List_of_Kazan_State_University%27s_rectors
# /wiki/List_of_universities_in_Russia
# /w/index.php?title=Kazan_Federal_University&action=edit&section=16
# #cite_ref-1
# /wiki/Old_Style_and_New_Style_dates
# #cite_ref-2
# #cite_ref-3
# http://www.ksu.ru/ustav/index.php
# #cite_ref-4
# http://government.ru/eng/smi/messages/10161/
# https://web.archive.org/web/20110724164323/http://government.ru/eng/smi/messages/10161/
# /wiki/Wayback_Machine
# #cite_ref-5
# http://kremlin.ru/acts/5793
# #cite_ref-6
# http://www.tatar-inform.ru/news/2009/10/22/190020
# https://web.archive.org/web/20120318020122/http://www.tatar-inform.ru/news/2009/10/22/190020/
# /wiki/Wayback_Machine
# #cite_ref-7
# http://government.ru/gov/results/10198/
# https://web.archive.org/web/20110724164405/http://government.ru/gov/results/10198/
# /wiki/Wayback_Machine
# #cite_ref-8
# https://archive.today/20120710023959/http://info.tatcenter.ru/science/86326.htm
# #cite_ref-9
# http://kpfu.ru/eng/about-university/facts-and-figures
# #cite_ref-10
# http://kpfu.ru/portal/docs/F1542656564/prezentaciya.pdf
# #cite_ref-11
# http://kpfu.ru/eng/admission/academics
# #cite_ref-12
# http://kpfu.ru/eng/about-university/facts-and-figures
# #cite_ref-13
# http://kpfu.ru/eng/international-cooperation/kfu-honorary-doctors-and-professors
# #cite_ref-14
# http://www-igbmc.u-strasbg.fr/yusupov/
# #cite_ref-15
# http://kpfu.ru/eng/academic-units/natural-sciences/institute-of-fundamental-medicine-and-biology/structure/departments/department-of-human-and-animal-physiology/research
# #cite_ref-16
# http://english.inserm.fr/
# #cite_ref-17
# http://kpfu.ru/eng/research-innovation/joint-projects
# #cite_ref-18
# http://kpfu.ru/eng/research-innovation/joint-projects
# #cite_ref-19
# http://kpfu.ru/eng/research-innovation/joint-projects
# #cite_ref-20
# http://www.utu.fi/en/sites/iii/project/Pages/home.aspx
# https://web.archive.org/web/20150518095521/http://www.utu.fi/en/sites/iii/project/Pages/home.aspx
# /wiki/Wayback_Machine
# #cite_ref-21
# http://www.utu.fi/en/sites/em-aurora/project/Pages/home.aspx
# #cite_ref-22
# https://arquivo.pt/wayback/20100529175653/http://eacea.ec.europa.eu/erasmus_mundus/programme/about_erasmus_mundus_en.php
# /w/index.php?title=Kazan_Federal_University&action=edit&section=17
# https://www.webcitation.org/6hH2jZROp?url=http://journals.mosgu.ru/zpu/article/download/236/279
# /wiki/Digital_object_identifier
# //doi.org/10.17805%2Fzpu.2016.1.29
# http://journals.mosgu.ru/zpu/article/view/236/279
# /w/index.php?title=Kazan_Federal_University&action=edit&section=18
# https://commons.wikimedia.org/wiki/Category:Kazan_University
# http://kpfu.ru/main_page?p_sub=16
# https://web.archive.org/web/20120204111301/http://www.ksu.ru/miku/eng/ekskurs/istoki/s3.php
# /wiki/Template:Federal_universities_of_Russia
# /wiki/Template_talk:Federal_universities_of_Russia
# //en.wikipedia.org/w/index.php?title=Template:Federal_universities_of_Russia&action=edit
# /wiki/Far_Eastern_Federal_District
# /wiki/Far_Eastern_Federal_University
# /wiki/North-Eastern_Federal_University
# /wiki/Volga_Federal_District
# /wiki/Kazan_(Volga_region)_Federal_University
# /wiki/Northwestern_Federal_District
# /wiki/Northern_(Arctic)_Federal_University
# /wiki/Immanuel_Kant_Baltic_Federal_University
# /wiki/Siberian_Federal_District
# /wiki/Siberian_Federal_University
# /wiki/Ural_Federal_District
# /wiki/Ural_Federal_University
# /wiki/Southern_Federal_District
# /wiki/Southern_Federal_University
# /wiki/North_Caucasian_Federal_District
# /wiki/North_Caucasian_Federal_University
# /wiki/Template:CDIO
# /wiki/Template_talk:CDIO
# //en.wikipedia.org/w/index.php?title=Template:CDIO&action=edit
# /wiki/CDIO
# /wiki/University_of_Johannesburg
# /wiki/University_of_Pretoria
# /wiki/Chisholm_Institute
# /wiki/Curtin_University
# /wiki/Queensland_University_of_Technology
# /wiki/RMIT_University
# /wiki/University_of_Sydney
# /wiki/University_of_the_Sunshine_Coast
# /wiki/Beijing_Institute_of_Petrochemical_Technology
# /wiki/Beijing_Jiaotong_University
# /wiki/Chengdu_University_of_Information_Technology
# /wiki/Shantou_University
# /wiki/Tsinghua_University
# /wiki/Yanshan_University
# /wiki/Taylor%27s_University
# /wiki/University_of_Auckland
# /wiki/Singapore_Polytechnic
# /wiki/Vietnam_National_University,_Ho_Chi_Minh_City
# /wiki/Helsinki_Metropolia_University_of_Applied_Sciences
# /wiki/Lahti_University_of_Applied_Sciences
# /wiki/Lapland_University_of_Applied_Sciences
# /wiki/Novia_University_of_Applied_Sciences
# /wiki/Savonia_University_of_Applied_Sciences
# /wiki/Sein%C3%A4joki_University_of_Applied_Sciences
# /wiki/Tampere_University_of_Applied_Sciences
# /wiki/Turku_University_of_Applied_Sciences
# /wiki/University_of_Turku
# /wiki/Astrakhan_State_University
# /wiki/Bauman_Moscow_State_Technical_University
# /wiki/Cherepovets_State_University
# /wiki/Don_State_Technical_University
# /wiki/Kazan_(Volga_region)_Federal_University
# /wiki/Moscow_Aviation_Institute
# /wiki/Moscow_Institute_of_Physics_and_Technology
# /wiki/National_Research_Nuclear_University_MEPhI_(Moscow_Engineering_Physics_Institute)
# /wiki/North-Eastern_Federal_University
# /wiki/Oryol_State_University
# /wiki/Saint_Petersburg_State_University_of_Aerospace_Instrumentation
# /wiki/Siberian_Federal_University
# /wiki/Skolkovo_Institute_of_Science_and_Technology
# /wiki/Tomsk_Polytechnic_University
# /wiki/Tomsk_State_University_of_Control_Systems_and_Radio-electronics
# /wiki/Ural_Federal_University
# /wiki/Blekinge_Institute_of_Technology
# /wiki/Chalmers_University_of_Technology
# /wiki/J%C3%B6nk%C3%B6ping_School_of_Engineering
# /wiki/Kristianstad_University
# /wiki/Link%C3%B6ping_University
# /wiki/Linnaeus_University
# /wiki/Lule%C3%A5_University_of_Technology
# /wiki/Royal_Institute_of_Technology
# /wiki/Ume%C3%A5_Institute_of_Technology
# /wiki/University_of_Sk%C3%B6vde
# /wiki/University_College_West
# /wiki/Aston_University
# /wiki/Lancaster_University
# /wiki/Queen%27s_University_Belfast
# /wiki/South_Eastern_Regional_College
# /wiki/Ulster_University
# /wiki/University_of_Bristol
# /wiki/University_of_Chichester
# /wiki/University_of_Leeds
# /wiki/University_of_Liverpool
# /wiki/University_of_Strathclyde
# /wiki/Hogeschool_Gent
# /wiki/Aarhus_University
# /wiki/Technical_University_of_Denmark
# /wiki/%C3%89cole_nationale_sup%C3%A9rieure_des_t%C3%A9l%C3%A9communications_de_Bretagne
# /wiki/Hochschule_Wismar
# /wiki/Polytechnic_University_of_Milan
# /wiki/Instituto_Superior_de_Engenharia_do_Porto
# /wiki/Polytechnic_University_of_Catalonia
# /wiki/Polytechnique_Montr%C3%A9al
# /wiki/Queen%27s_University
# /wiki/Sheridan_College
# /wiki/University_of_Calgary
# /wiki/University_of_Manitoba
# /wiki/Arizona_State_University
# /wiki/California_State_University,_Northridge
# /wiki/Duke_University
# /wiki/Embry%E2%80%93Riddle_Aeronautical_University
# /wiki/Massachusetts_Institute_of_Technology
# /wiki/Naval_Postgraduate_School
# /wiki/Pennsylvania_State_University
# /wiki/Stanford_University
# /wiki/United_States_Naval_Academy
# /wiki/University_of_Arkansas
# /wiki/University_of_Colorado
# /wiki/University_of_Michigan
# /wiki/University_of_Notre_Dame
# /wiki/Catholic_University_of_the_Most_Holy_Conception
# /wiki/University_of_Chile
# /wiki/University_of_Los_Lagos
# /wiki/University_of_Santiago,_Chile
# /wiki/ICESI_University
# /wiki/National_University_of_Colombia
# /wiki/Pontifical_Xavierian_University
# /wiki/University_of_Antioquia
# /wiki/University_of_Santo_Tomas
# /wiki/University_of_Quind%C3%ADo
# https://en.wikipedia.org/w/index.php?title=Kazan_Federal_University&oldid=880349504
# /wiki/Help:Category
# /wiki/Category:Kazan_(Volga_region)_Federal_University
# /wiki/Category:Educational_institutions_established_in_1804
# /wiki/Category:Universities_in_Volga_Region
# /wiki/Category:Universities_in_Kazan
# /wiki/Category:History_of_Tatarstan
# /wiki/Category:1804_establishments_in_the_Russian_Empire
# /wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:Coordinates_on_Wikidata
# /wiki/Category:Instances_of_Infobox_university_using_image_size
# /wiki/Category:Articles_containing_Russian-language_text
# /wiki/Category:Articles_containing_Tatar-language_text
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_April_2014
# /wiki/Category:Commons_category_link_is_on_Wikidata
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=
D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82%D1%8B
# https://tr.wikipedia.org/wiki/Kazan_Devlet_%C3%9Cniversitesi
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B0%D0%B7%D0%B0%D0%BD%D1%81%D1%8C%D0%BA%D0%B8%D0%B9_%D1%84%D0%B5%D0%B4%D0%B5%D1%80%D0%B0%D0%BB%D1%8C%D0%BD%D0%B8%D0%B9_%D1%83%D0%BD%D1%96%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82
# https://zh.wikipedia.org/wiki/%E5%96%80%E5%B1%B1%E5%9B%BD%E7%AB%8B%E5%A4%A7%E5%AD%A6
# https://www.wikidata.org/wiki/Special:EntityPage/Q113788#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://foundation.wikimedia.org/wiki/Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kazan_Federal_University&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# //www.mediawiki.org/

# %% [markdown]
# ## Извлечение статей

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

html = urlopen('https://en.wikipedia.org/wiki/Kazan_Federal_University')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    if 'href' in link.attrs:
        print(link.attrs['href'])

# %% [markdown]
# ## Случайный обход

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kazan')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)

# %% [markdown]
# ## Рекурсивный краулинг по всему сайту

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

# %% [markdown]
# ## Сбор данных со всего сайта

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        print(bs.find(id ='mw-content-text').find_all('p')[0])
        print(bs.find(id='ca-edit').find('span').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')
    
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

# %% [markdown]
# ## Краулинг по Интернету

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, includeUrl):
    includeUrl = '{}://{}'.format(urlparse(includeUrl).scheme, urlparse(includeUrl).netloc)
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bs.find_all('a', href=re.compile('^(/|.*'+includeUrl+')')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith('/')):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bs, excludeUrl):
    externalLinks = []
    #Finds all links that start with "http" that do
    #not contain the current URL
    for link in bs.find_all('a', href=re.compile('^(http|www)((?!'+excludeUrl+').)*$')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks

def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bs = BeautifulSoup(html, 'html.parser')
    externalLinks = getExternalLinks(bs, urlparse(startingPage).netloc)
    if len(externalLinks) == 0:
        print('No external links, looking around the site for one')
        domain = '{}://{}'.format(urlparse(startingPage).scheme, urlparse(startingPage).netloc)
        internalLinks = getInternalLinks(bs, domain)
        return getRandomExternalLink(internalLinks[random.randint(0,
                                    len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print('Random external link is: {}'.format(externalLink))
    followExternalOnly(externalLink)
            
followExternalOnly('https://kpfu.ru/computing-technology')

# %% [markdown]
# ## Сбор внешних ссылок

# %%
# Collects a list of all external URLs found on the site
allExtLinks = set()
allIntLinks = set()


def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    domain = '{}://{}'.format(urlparse(siteUrl).scheme,
                              urlparse(siteUrl).netloc)
    bs = BeautifulSoup(html, 'html.parser')
    internalLinks = getInternalLinks(bs, domain)
    externalLinks = getExternalLinks(bs, domain)

    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.add(link)
            getAllExternalLinks(link)


allIntLinks.add('https://kpfu.ru/computing-technology')
getAllExternalLinks('https://kpfu.ru/computing-technology')
